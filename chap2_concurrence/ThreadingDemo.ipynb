# %%
from threading import Thread

def simple_worker():
    print("hello")

t = Thread(target=simple_worker)
print(t.ident)
t.start()
print(t.ident)
#t.start() #RuntimeError
# Out:
# None
# hello
# 32572
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 10
#       8 t.start()
#       9 print(t.ident)
# ---> 10 t.start()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:989, in Thread.start(self)
#     986     raise RuntimeError("thread.__init__() not called")
#     988 if self._started.is_set():
# --> 989     raise RuntimeError("threads can only be started once")
#     991 with _active_limbo_lock:
#     992     _limbo[self] = self
#
# RuntimeError: threads can only be started once
